# %% [markdown]
# 최고의 학습은?

# %% [markdown]
# # 모듈 & data import

# %%
from IPython.display import Image
img=Image("C:/Users/z002t5wz/aiffel/dataton/athlete_events/bird.jpg")
img

# %%
import os
from os.path import join

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# origin_data 변수를 만들기
athlete_events_path = ('C:/Users/z002t5wz/aiffel/dataton/athlete_events/athlete_events.csv')
noc_regions_path = ('C:/Users/z002t5wz/aiffel/dataton/athlete_events/noc_regions.csv')
origin_athlete_events = pd.read_csv(athlete_events_path)
origin_noc_regions = pd.read_csv(noc_regions_path)

origin_athlete_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ## 데이터 목록

# %% [markdown]
# - Content
#
#         271116 rows and 15 columns;<br>
#
#         ID - Unique number for each athlete;<br>
#         Name - Athlete's name;<br>
#         Sex - M or F;<br>
#         Age - Integer;<br>
#         Height - In centimeters;<br>
#         Weight - In kilograms;<br>
#         Team - Team name;<br>
#         NOC - National Olympic Committee 3-letter code;<br>
#         Games - Year and season;<br>
#         Year - Integer;<br>
#         Season - Summer or Winter;<br>
#         City - Host city;<br>
#         Sport - Sport;<br>
#         Event - Event;<br>
#         Medal - Gold, Silver, Bronze, or NA.<br>

# %%
origin_noc_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
origin_noc_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# ## 데이터 복사

# %%
data_fix=origin_athlete_events.copy()
data_remove=origin_athlete_events.copy()
data_noc= origin_noc_regions.copy()

# %%
#data_fix.info()

# %% [markdown]
# ## Data결합
#
#         기존데이터의 'NOC'-국가코드 의 값들과 나라이름을 맞춰주는 작업

# %%
data_fix = pd.merge(data_fix, data_noc, on='NOC', how='left')

# %%
# data_fix=data_fix.drop(labels =['region_x', 'notes_x', 'region_y', 'notes_y'], axis = 1)
# data_fix

# %%
data_fix.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %% [markdown]
# # 결측치확인

# %%
data_fix.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# notes     266077
# dtype: int64

# %% [markdown]
# ## 결측치 보상여부 결정
#
#         - 결측치의 보상방법:
#             - 각 종목별 평균값을 얻어 보상하는 방법
#                 - 종목별 평균을 추출하고 종목별 결측치에 채워넣는 함수실행 미완성
#             - 결측치를 '0'으로 보상하는 방법
#             - 결측치를 전체 평균값으로 보상하는 방법 <선정>

# %% [markdown]
# # 한국인 출전자의 데이터 분석

# %%
data_kor = data_fix[(data_fix.NOC == 'KOR')] 
data_kor.head()
# Out:
#         ID         Name Sex   Age  Height  Weight         Team  NOC  \
# 2520  1422  Ahn Jin-Soo   M  18.0   178.0    70.0  South Korea  KOR
# 2521  1422  Ahn Jin-Soo   M  18.0   178.0    70.0  South Korea  KOR
# 2522  1422  Ahn Jin-Soo   M  18.0   178.0    70.0  South Korea  KOR
# 2523  1422  Ahn Jin-Soo   M  18.0   178.0    70.0  South Korea  KOR
# 2524  1422  Ahn Jin-Soo   M  20.0   178.0    70.0  South Korea  KOR
#
#             Games  Year  Season         City                 Sport  \
# 2520  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2521  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2522  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2523  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2524  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                   Event Medal       region  \
# 2520           Cross Country Skiing Men's 10 kilometres   NaN  South Korea
# 2521           Cross Country Skiing Men's 30 kilometres   NaN  South Korea
# 2522  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN  South Korea
# 2523  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN  South Korea
# 2524           Cross Country Skiing Men's 10 kilometres   NaN  South Korea
#
#      notes
# 2520   NaN
# 2521   NaN
# 2522   NaN
# 2523   NaN
# 2524   NaN

# %% [markdown]
# ## 불필요한 데이터 drop()

# %%
# data_kor=data_kor.drop(labels =['region_x', 'notes_x', 'region_y', 'notes_y'], axis = 1)
# data_kor

# %% [markdown]
# ## KOR 결측치 확인

# %%
data_kor.isnull().head()
# Out:
#          ID   Name    Sex    Age  Height  Weight   Team    NOC  Games   Year  \
# 2520  False  False  False  False   False   False  False  False  False  False
# 2521  False  False  False  False   False   False  False  False  False  False
# 2522  False  False  False  False   False   False  False  False  False  False
# 2523  False  False  False  False   False   False  False  False  False  False
# 2524  False  False  False  False   False   False  False  False  False  False
#
#       Season   City  Sport  Event  Medal  region  notes
# 2520   False  False  False  False   True   False   True
# 2521   False  False  False  False   True   False   True
# 2522   False  False  False  False   True   False   True
# 2523   False  False  False  False   True   False   True
# 2524   False  False  False  False   True   False   True

# %%
data_kor.isnull().sum()
# Out:
# ID           0
# Name         0
# Sex          0
# Age         54
# Height     579
# Weight     577
# Team         0
# NOC          0
# Games        0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal     3826
# region       0
# notes     4464
# dtype: int64

# %%
#data_kor.columns

# %%
# data_kor[['Height']].apply(lambda x: x.fillna(x.mean())).astype(np.int)
# data_kor['Height']

# %% [markdown]
# ## 전처리함수 만들기

# %%
def feature_eng(data_kor):

        data_kor['Sex'] = data_kor['Sex'].map({'F': 0, 'M': 1})
        data_kor['Medal'] = data_kor['Medal'].map({'Gold': 3, 'Silver': 2, 'Bronze':1, np.nan: 0})
        #data_fix=data_fix.fillna(0) 
        return data_kor


def missing_value(data_kor):
        missing_col = ['Age', 'Height', 'Weight']
        for i in missing_col:
            data_kor[[i]]=data_kor[[i]].apply(lambda x: x.fillna(x.mean())).astype(np.int)
        
        
        return data_kor

data_kor = feature_eng(data_kor)
data_kor = missing_value(data_kor)

# %%
#data_kor.head()

# %%
data_kor.isnull().sum()
# Out:
# ID           0
# Name         0
# Sex          0
# Age          0
# Height       0
# Weight       0
# Team         0
# NOC          0
# Games        0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# region       0
# notes     4464
# dtype: int64

# %% [markdown]
# 메달별 집계

# %%
g_medals_kor = data_kor[(data_kor['Medal'] == 3)]
g_medals_kor.head()
# Out:
#         ID            Name  Sex  Age  Height  Weight         Team  NOC  \
# 6364  3567  An Byeong-Geun    1   22     172      78  South Korea  KOR
# 6383  3581     An Han-Bong    1   23     163      62  South Korea  KOR
# 6405  3595      An Sang-Mi    0   18     155      48  South Korea  KOR
# 6420  3604       Viktor An    1   20     170      65  South Korea  KOR
# 6421  3604       Viktor An    1   20     170      65  South Korea  KOR
# 6375   Wrestling Men's Featherweight, Greco-Roman      1  South Korea   NaN
# 6387                   Table Tennis Men's Doubles      1  South Korea   NaN
# 6393                    Handball Women's Handball      1  South Korea   NaN
# 6419   Short Track Speed Skating Men's 500 metres      1  South Korea   NaN
# 12372                   Handball Women's Handball      1  South Korea   NaN

# %% [markdown]
# ## 한국인 출전자 데이터 결과 확인

# %% [markdown]
# ### 연도별 선수현황

# %%
#data_kor.value_counts()

# %%
plt.figure(figsize=(10, 6))
plt.tight_layout()
sns.countplot(data_kor['Year']) #hue="Season"별 확인
plt.title('no. of Participants [Fig 3.3.3]')
# Out:
# Text(0.5, 1.0, 'no. of Participants [Fig 3.3.3]')

# %% [markdown]
# - 주석 [fig 3.3.3] 1988올림픽 최다 참여
# - 동계올림픽과 하계올림픽의 참여자수 변화추이
# - 1994년 동계올림픽 출전, 꾸준히 참여자수 증가

# %% [markdown]
# ### 나이별 출전자 수

# %%
plt.figure(figsize=(10,6))
plt.tight_layout()
sns.countplot(data_kor['Age'])
plt.title('Distribution of participants')
# Out:
# Text(0.5, 1.0, 'Distribution of participants')

# %% [markdown]
# - 출전 선수중 가장어린 13세의 선수와 연장자인 48세의 선수가 참가한 것을 확인 할 수 있으며, 전반적인 10대 후반에서 30대 초반사이에 선수들이 분포하고 있습니다.

# %% [markdown]
# ### 성별 출전자

# %%
plt.figure(figsize=(10, 5))
plt.tight_layout()
sns.countplot(data_kor['Sex'])
plt.title('no. of participants by Sex')
# Out:
# Text(0.5, 1.0, 'no. of participants by Sex')

# %% [markdown]
# ### 전체 메달집계

# %%
kor_medal_count = data_kor['Medal']
kor_medal_count.value_counts()
# Out:
# 0    3826
# 2     232
# 3     221
# 1     185
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(7, 4))
sns.countplot(kor_medal_count)
plt.title("KOR's Medal")
plt.show()

# %% [markdown]
# 메달따기 힘들죠?

# %% [markdown]
# ### 나이별 금메달

# %%
plt.figure(figsize=(12,7))
plt.tight_layout()
sns.countplot(g_medals_kor['Age'])
plt.title('Distribution of Gold Medals')


plt.figure(figsize=(6,4))
plt.tight_layout()
sns.countplot(s_medals_kor['Age'])
plt.title('Distribution of Silver Medals')


plt.figure(figsize=(6,4))
plt.tight_layout()
sns.countplot(b_medals_kor['Age'])
plt.title('Distribution of Bronze Medals')
# Out:
# Text(0.5, 1.0, 'Distribution of Bronze Medals')

# %% [markdown]
# - 주석: 메달추이상황을 보니 어떤 종목들에서 출전하고 있는지 궁금해 집니다. 우리 선수들의 참여종목을 살펴보겠습니다.

# %% [markdown]
# ### 시간에 따른 종목별 출전자 분포

# %%
#data_kor['Sport'].value_counts()

# %%
# 'Year'에 따른  참여'Sport'를 남녀별 분포도로 확인
plt.rcParams['figure.figsize'] = [7, 9] # setting figure size
sns.scatterplot(data=data_kor, x='Year', y= 'Sport', hue='Sex')
#sns.set(rc={'figure.figsize':(20,10)})
plt.title('Sports over Time')
plt.show()

# %% [markdown]
# - 경제발전에 따른 스포츠 참여종목수가 늘어남을 알 수 있다, 특히 1988년도 88올림픽 이후 다양한 종목에 출전하고 있다

# %% [markdown]
# -

# %% [markdown]
# ### 한국인 첫 금메달 리스트는 누구일까요?

# %%
g_medals_kor = data_kor[(data_kor['Medal'] == 3)]
g_medals_kor.sort_values(by='Year').head(1)
# Out:
#             ID           Name  Sex  Age  Height  Weight         Team  NOC  \
# 264787  132508  Yang Jeong-Mo    1   23     165      62  South Korea  KOR
#
#               Games  Year  Season      City      Sport  \
# 264787  1976 Summer  1976  Summer  Montreal  Wrestling
#
#                                            Event  Medal       region notes  \
# 264787  Wrestling Men's Featherweight, Freestyle      3  South Korea   NaN
#
#         Cluster
# 264787      NaN

# %% [markdown]
# - 1976년 양정모 선수가 레슬링에서 우리나라에 첫 금메달을 안겨주었습니다.

# %%
img_yjm=Image("C:/Users/z002t5wz/aiffel/dataton/athlete_events/1st_gold_medalist_kr.jpg")
img_yjm

# %%
first_medalist=g_medals_kor.sort_values(by = 'Year', inplace = True, ascending=True)
first_medalist

# %% [markdown]
# # 메달과 신체조건 (나이, 키, 몸무게 등) 상관 관계 알아보기

# %%
#data_kor

# %%
#data_kor=data_kor.drop(labels =['region_x', 'notes_x', 'region_y', 'notes_y'], axis = 1)

# %%
#data_kor.columns

# %%
#data_kor.head()

# %% [markdown]
# ## 상관관계 분석(한국)

# %%
# data_kor의 상관관계분석하기
corr_data_kor = data_kor[['Sex', 'Age', 'Height', 'Weight', 'Year', 'Medal']].corr().round(2)
corr_data_kor
# Out:
#          Sex   Age  Height  Weight  Year  Medal
# Sex     1.00  0.22    0.40    0.42 -0.17  -0.12
# Age     0.22  1.00    0.19    0.22  0.12   0.00
# Height  0.40  0.19    1.00    0.78  0.09   0.02
# Weight  0.42  0.22    0.78    1.00  0.07   0.04
# Year   -0.17  0.12    0.09    0.07  1.00   0.12
# Medal  -0.12  0.00    0.02    0.04  0.12   1.00

# %%
# 상관관계분석 결과 시각화하기 
'''각 인자들의 상관관계가 높다고 해서 인과관계가 있다는 것은 아님을 유의'''

sns.set(rc = {'figure.figsize':(7,4)})
sns.heatmap(data = corr_data_kor, annot=True)
plt.title('Heatmap By Correlation')
plt.show()

# %% [markdown]
# - 전반적으로 상관계수들이 <0.3 이하로 집중되어 있다. 메달과 신체적 조건과의 상관관계가 있지 않음을 알수 있다.
# - 개인의 노력은 수치화 할 수 없다!!!

# %% [markdown]
# ## 상관관계분석 (전체)

# %%
# 전체 원데이터 상관관계분석하기
corr_data_fix = data_fix[['Sex', 'Age', 'Height', 'Weight', 'Year', 'Medal']].corr().round(2)
corr_data_fix
# Out:
#          Age  Height  Weight  Year
# Age     1.00    0.14    0.21 -0.12
# Height  0.14    1.00    0.80  0.05
# Weight  0.21    0.80    1.00  0.02
# Year   -0.12    0.05    0.02  1.00

# %%
# 상관관계분석 결과 시각화하기 
'''각 인자들의 상관관계가 높다고 해서 인과관계가 있다는 것은 아님을 유의'''

sns.set(rc = {'figure.figsize':(7,4)})
sns.heatmap(data = corr_data_fix, annot=True)
plt.title('Heatmap By Correlation')
plt.show()

# %% [markdown]
# ## 군집분석
#
#         'Age','Height'등의 신체조건과의 상관관계가 있을까라는 의문으로 해당데이터를 기준으로 유사도를 확인해 본다

# %% [markdown]
# ### 모듈 Import

# %%
# 군집분석

# sklearn라이브러리 중 필요한 모듈을 호출
from sklearn.cluster import KMeans
from sklearn import preprocessing

#data_kor 중 'Age',' Height', 'Weight'를 골라내 temp_var로 저장
temp_var = data_kor[['Height', 'Age']] #이중괄호[[]] dafaframe으로 반환
print(type(temp_var))
temp_var.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       Height  Age
# 2520     178   18
# 2521     178   18
# 2522     178   18
# 2523     178   18
# 2524     178   20

# %%
#temp_var.isnull().sum()

# %% [markdown]
# ### 데이터 정규화

# %%
# sklearn의 preprocessing을 이용해 Feature의 scale이 다른 각 값들을 정규화
temp_var = preprocessing.StandardScaler().fit(temp_var).transform(temp_var)

# %% [markdown]
# ### 모델 setting

# %%
# 군집분석을 하기 위해 Kmeans 변수를 만들고 군집분석 초기 모델을 할당
Kmeans = KMeans(n_clusters=3, # 군집 개수는 3개 도출
                init='k-means++', # 모델 초기화 방법은 K-means++ 사용
                n_init=10, # 모델의 초기화 횟수 (초기화-학습 10회 반복 후 최선의 결과 선택)
                verbose=True, # 군집분석 수행 중 각 단계별 메세지 출력 여부
                max_iter=10000, # 최대 반복 횟수
                random_state=1111 # 랜덤시드 고정
                               )

# %% [markdown]
# ### fitting

# %%
# 할당된 군집분석 모델에 temp_var를 적용(fit)
Kmeans.fit(temp_var)
# Out:
# Initialization complete
# Iteration 0, inertia 4405.118524488026
# Iteration 1, inertia 4059.3555925007095
# Iteration 2, inertia 4033.5777541060756
# Iteration 3, inertia 3981.613805709513
# Iteration 4, inertia 3962.847790891756
# Iteration 5, inertia 3954.027863181675
# Iteration 6, inertia 3948.224118348672
# Iteration 7, inertia 3943.8723402339842
# Iteration 8, inertia 3942.4326240003747
# Iteration 9, inertia 3941.5116001317483
# Iteration 10, inertia 3941.043780949659
# Converged at iteration 10: center shift 5.457816342067244e-05 within tolerance 0.0001000000000000001.
# Initialization complete
# Iteration 0, inertia 5647.6505005784165
# Iteration 1, inertia 4850.955132998656
# Iteration 2, inertia 4722.520420888355
# Iteration 3, inertia 4654.145298093656
# Iteration 4, inertia 4597.167782950615
# Iteration 5, inertia 4500.179653538651
# Iteration 6, inertia 4369.381177469601
# Iteration 7, inertia 4216.716449275233
# Iteration 8, inertia 4117.158276532335
# Iteration 9, inertia 4078.036107995379
# Iteration 10, inertia 4041.6093150416655
# Iteration 11, inertia 3985.4713225792816
# Iteration 12, inertia 3967.4646323805955
# Iteration 13, inertia 3957.09417107791
# Iteration 14, inertia 3950.388991345011
# Iteration 15, inertia 3947.2715617822355
# Iteration 16, inertia 3943.6716117266583
# Iteration 17, inertia 3942.215752404607
# Iteration 18, inertia 3941.4631297598053
# Iteration 19, inertia 3941.0437809496584
# Iteration 8, inertia 3943.8723402339833
# Iteration 9, inertia 3942.4326240003747
# Iteration 10, inertia 3941.511600131749
# Iteration 11, inertia 3941.0437809496584
# Converged at iteration 11: center shift 5.457816342067259e-05 within tolerance 0.0001000000000000001.
# Initialization complete
# Iteration 0, inertia 5955.175833945245
# Iteration 1, inertia 5130.176259703153
# Iteration 2, inertia 4824.809349681287
# Iteration 3, inertia 4580.274493514029
# Iteration 4, inertia 4398.005810783241
# Iteration 5, inertia 4337.056699651889
# Iteration 6, inertia 4291.678023508817
# Iteration 7, inertia 4277.9527256262545
# Iteration 8, inertia 4276.470165861133
# Iteration 9, inertia 4275.4162478737735
# Iteration 10, inertia 4272.807463623029
# Iteration 11, inertia 4269.534278711948
# Iteration 12, inertia 4266.267585349603
# Iteration 13, inertia 4264.2678251092375
# Iteration 14, inertia 4263.895864996956
# Converged at iteration 14: center shift 7.864775047194728e-05 within tolerance 0.0001000000000000001.
# Initialization complete
# Iteration 0, inertia 4942.6045650783935
# Iteration 1, inertia 4385.458624759624
# Iteration 2, inertia 4252.411839208349
# Iteration 3, inertia 4139.78181165755
# Iteration 4, inertia 4077.4038909368055
# Iteration 5, inertia 4023.23824813354
# Iteration 6, inertia 3965.9946186460365
# Iteration 7, inertia 3950.0233192098212
# Iteration 8, inertia 3941.6079366541617
# Iteration 9, inertia 3940.6399917303206
# Converged at iteration 9: strict convergence.
# KMeans(max_iter=10000, n_clusters=3, random_state=1111, verbose=True)

# %% [markdown]
# ### Clustering

# %%
# 분류된 각 군집이름(Label)을 변수 Cluster_label로 할당
cluster_label = Kmeans.labels_

# 할당된 Cluster_label을 temp_var1의 Cluster열 값으로 할당
data_kor['Cluster'] = pd.DataFrame(cluster_label)
data_kor.head(5)
# Out:
#         ID         Name  Sex  Age  Height  Weight         Team  NOC  \
# 2520  1422  Ahn Jin-Soo    1   18     178      70  South Korea  KOR
# 2521  1422  Ahn Jin-Soo    1   18     178      70  South Korea  KOR
# 2522  1422  Ahn Jin-Soo    1   18     178      70  South Korea  KOR
# 2523  1422  Ahn Jin-Soo    1   18     178      70  South Korea  KOR
# 2524  1422  Ahn Jin-Soo    1   20     178      70  South Korea  KOR
#
#             Games  Year  Season         City                 Sport  \
# 2520  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2521  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2522  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2523  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 2524  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                   Event  Medal       region  \
# 2520           Cross Country Skiing Men's 10 kilometres      0  South Korea
# 2521           Cross Country Skiing Men's 30 kilometres      0  South Korea
# 2522  Cross Country Skiing Men's 10/15 kilometres Pu...      0  South Korea
# 2523  Cross Country Skiing Men's 4 x 10 kilometres R...      0  South Korea
# 2524           Cross Country Skiing Men's 10 kilometres      0  South Korea
#
#      notes  Cluster
# 2520   NaN      0.0
# 2521   NaN      0.0
# 2522   NaN      1.0
# 2523   NaN      1.0
# 2524   NaN      2.0

# %%
# data_kor의 Cluster열의 각 고유값 계산하기
data_kor['Cluster'].value_counts()
# Out:
# 1.0    6
# 0.0    3
# 2.0    2
# Name: Cluster, dtype: int64

# %%
temp_var = data_kor.groupby('Cluster').mean()
temp_var
# Out:
#              ID  Sex        Age  Height  Weight         Year  Medal
# Cluster
# 0.0      1422.0  1.0  18.666667   178.0    70.0  1992.666667    0.0
# 1.0      1422.0  1.0  22.000000   178.0    70.0  1996.000000    0.0
# 2.0      1422.0  1.0  20.000000   178.0    70.0  1994.000000    0.0

# %%
#temp_var.T

# %% [markdown]
# ### 군집별 시각화

# %% [markdown]
# #### Cluster별 군집화

# %%
# 각 군집별 산포도로 시각화

sns.scatterplot(data=data_kor, x='Age', y='Medal', hue='Cluster')
plt.title('Scatter Chart By Cluster')
plt.show()

# %% [markdown]
# - Cluster별 주요 구분기준은 나이이며, 18.6세, 20.4세, 19세를 기준으로 세 그룹으로 나뉘어지며 이에 따른 메달과의 상관관계는 '0'으로 나타난다.

# %% [markdown]
# #### Hight & Weight 별 메달분포

# %%
# 각 군집별 산포도로 시각화

sns.scatterplot(data=data_kor, x='Height', y='Weight', hue='Medal')
plt.title('Scatter Chart By Height & Weight')
plt.show()

# %% [markdown]
# ## 상관관계 및 Clustering 결론:
#         다른 분석자료에서 키와 몸무게에 따른 메달과의 상관관계를 선형적인 관계로 파악하였으나,,,,키와 몸무게는 이미 선형적인 관계이기 때문에 메
#         달과의 상관성이 있는 것 처럼 보이지만 현 분석에서는 상관관계 및 신체조건에 따른 Clustering이 의미 없음을 보여준다. 비메달리스트의 키와
#         몸무게 역시 선형관계를 보이고 있으므로 분석을 뒷받침하고 있다.
#
#         하지만 두 분석모델은 비학습된모델입니다. 따라서 모델을 학습 시킨 후 결과가 어떻게 나올지? 또다른 궁금증을 주었습니다.

# %% [markdown]
# # ...next

# %%
data_fix
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
#              region notes
# 0             China   NaN
# 1             China   NaN
# 2           Denmark   NaN
# 3           Denmark   NaN
# 4       Netherlands   NaN
# ...             ...   ...
# 271111       Poland   NaN
# 271112       Poland   NaN
# 271113       Poland   NaN
# 271114       Poland   NaN
# 271115       Poland   NaN
#
# [271116 rows x 17 columns]

# %% [markdown]
# ## 데이터 전처리

# %%
def feature_eng(data_fix):

        data_fix['Sex'] = data_fix['Sex'].map({'F': 0, 'M': 1})
        data_fix['Medal'] = data_fix['Medal'].map({'Gold': 3, 'Silver': 2, 'Bronze':1, np.nan: 0})
        #data_fix=data_fix.fillna(0) 
 
        return data_fix


def missing_value(data_fix):
        missing_col = ['Age', 'Height', 'Weight']
        for i in missing_col:
            data_fix[[i]]=data_fix[[i]].apply(lambda x: x.fillna(x.mean())).astype(np.int)
        
        
        return data_fix

data_fix = feature_eng(data_fix)
data_fix = missing_value(data_fix)

# %%
data_fix.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Med
Ice Hockey                        Ice Hockey Men's Ice Hockey
# 41            Gymnastics             Gymnastics Men's Individual All-Around
# 42            Gymnastics                   Gymnastics Men's Team All-Around
# 43            Gymnastics                    Gymnastics Men's Floor Exercise
# 44            Gymnastics                       Gymnastics Men's Horse Vault
# 45            Gymnastics                     Gymnastics Men's Parallel Bars
# 46            Gymnastics                    Gymnastics Men's Horizontal Bar
# 47            Gymnastics                             Gymnastics Men's Rings
# 48            Gymnastics                   Gymnastics Men's Pommelled Horse
# 49            Gymnastics             Gymnastics Men's Individual All-Around
#
#     Medal       region notes
# 0       0        China   NaN
# 1       0        China   NaN
# 2       0      Denmark   NaN
# 3       3      Denmark   NaN
# 4       0  Netherlands   NaN
# 5       0  Netherlands   NaN
# 6       0  Netherlands   NaN
# 7       0  Netherlands   NaN
# 8       0  Netherlands   NaN
# 9       0  Netherlands   NaN
# 10      0          USA   NaN
# 11      0          USA   NaN
# 12      0          USA   NaN
# 13      0          USA   NaN
# 14      0          USA   NaN
# 15      0          USA   NaN
# 16      0          USA   NaN
# 17      0          USA   NaN
# 18      0          USA   NaN
# 19      0          USA   NaN
# 20      0          USA   NaN
# 21      0          USA   NaN
# 22      0          USA   NaN
# 23      0          USA   NaN
# 24      0          USA   NaN
# 25      0          USA   NaN
# 26      0  Netherlands   NaN
# 27      0  Netherlands   NaN
# 28      0      Finland   NaN
# 29      0      Finland   NaN
# 30      0      Finland   NaN
# 31      0      Finland   NaN
# 32      0      Finland   NaN
# 33      0      Finland   NaN
# 34      0      Finland   NaN
# 35      0      Finland   NaN
# 36      0      Finland   NaN
# 37      1      Finland   NaN
# 38      1      Finland   NaN
# 39      0      Finland   NaN
# 40      1      Finland   NaN
# 41      1      Finland   NaN
# 42      3      Finland   NaN
# 43      0      Finland   NaN
# 44      3      Finland   NaN
# 45      0      Finland   NaN
# 46      0      Finland   NaN
# 47      0      Finland   NaN
# 48      3      Finland   NaN
# 49      0      Finland   NaN

# %%
data_fix['Sex'].value_counts()
# Out:
# 1    196594
# 0     74522
# Name: Sex, dtype: int64

# %% [markdown]
# ## 역대 top-10 참가국

# %%
top_10_countries = data_fix['Team'].value_counts().nlargest(10)
top_10_countries
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
# plot for top 10 countries
plt.figure(figsize=(9,5))
sns.barplot(x = top_10_countries.index,y = top_10_countries)
plt.xlabel('Teams')
plt.ylabel('Count of Team Participation')
plt.title('Top 10 Countries Participated In Olympics')
plt.show()

# %% [markdown]
# ## 하계올림픽 참가자 수 over time

# %%
# Atheletes Participated in Summer Olympics
athletes_per_year = data_fix[data_fix['Season']=='Summer'].groupby('Year')['ID'].count().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=athletes_per_year, x="Year", y="ID")
plt.xlabel('Year')
plt.ylabel('No of Athletes')
plt.show()

# %% [markdown]
# ## 역대참가자와 미국GDP와의 비교

# %%
# 미국 GDP 데이터 취득 및 기존데이터와 병합
gdpus_path = ('C:/Users/z002t5wz/aiffel/dataton/athlete_events/gdpus.csv')
'''Department US webpage 참조 -Current-Dollar and "Real" Gross Domestic Product'''
gdpus = pd.read_csv(gdpus_path, thousands = ',') # 출전선수와 scale을 맞추기위해 Billion 단위로 입력

# 병합 (GDP +올림픽데이터)
data_merge = pd.merge(data_fix, gdpus, on='Year', how='left')
data_merge['USGDP'] = data_merge['USGDP'].fillna(0) 

# (GDP +올림픽데이터+ 연도별 출전선수총계)
data_merge = pd.merge(data_merge, athletes_per_year, on='Year', how='left')

# twinplot 시각화
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

sns.lineplot(ax = ax1, data = data_merge, x = 'Year', y = 'USGDP', color = 'green')
sns.lineplot(ax = ax2, data = data_merge, x = 'Year', y = 'ID_y', color = 'red')
ax1.legend(['US GDP'])
ax2.legend(['no. of Participants'])
ax1.set_ylabel('US Billion Dollars')
ax2.set_ylabel('no of Participants')
plt.show()

# %% [markdown]
# ## 최다 메달 획득 국가

# %% [markdown]
# ### 금메달을 가장 많이 획득한 국가 top10

# %%
count_medal = pd.crosstab(index = data_fix['NOC'], columns = data_fix['Medal'])
medal_count = count_medal[[1,2,3]]
medal_count

sorted_gold=medal_count[[3]].sort_values(by=[3], ascending=False)
top10_gold = sorted_gold[:10]
top10_gold

plt.figure(figsize=(12,6))
sns.barplot(data=top10_gold, x=top10_gold.index, y=top10_gold[3], palette="Greens")
plt.xlabel('NOC')
plt.ylabel('Count of Gold_medal')
plt.show()

# %% [markdown]
# ### 은메달을 가장 많이 획득한 국가 top10

# %%
sorted_silver=medal_count[[2]].sort_values(by=[2], ascending=False)
top10_silver = sorted_silver[:10]
top10_silver

plt.figure(figsize=(12,6))
sns.barplot(data=top10_silver, x=top10_silver.index, y=top10_silver[2], palette="Blues")
plt.xlabel('NOC')
plt.ylabel('Count of Sliver_medal')
plt.show()

# %% [markdown]
# ### 동메달을 가장 많이 획득한 국가 top10

# %%
sorted_bronze=medal_count[[1]].sort_values(by=[1], ascending=False)
top10_bronze = sorted_bronze[:10]
top10_bronze

plt.figure(figsize=(12,6))
sns.barplot(data=top10_bronze, x=top10_bronze.index, y=top10_bronze[1], palette="Reds")
plt.xlabel('NOC')
plt.ylabel('Count of Bronze_medal')
plt.show()

# %% [markdown]
# ###  종류 상관없이 메달을 가장 많이 획득한 국가 top10

# %%
total_medal= data_fix.copy()
total_medal['Medal'] = total_medal['Medal'].replace(0,np.nan)

medalist = total_medal[total_medal['Medal'].isnull() == False]
medalist.head(10)

total_medal_count = pd.crosstab(index=medalist['NOC'], columns = medalist['Medal'].count())
total_medal_count = total_medal_count.sort_values(by=39783, ascending=False)
total_medal_count = total_medal_count[:10]

plt.figure(figsize=(12,6))
sns.barplot(data=total_medal_count, x=total_medal_count.index, y=total_medal_count[39783], palette="Greys")
plt.xlabel('NOC')
plt.ylabel('Count of Total_medal')
plt.show()
